# %% [markdown]
# <a href="https://colab.research.google.com/github/y-Shreya21/fundamental_of_ml/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

POPULATION_SIZE = 6
CHROMOSOME_LENGTH = 5
GENERATIONS = 100
MUTATION_RATE = 0.01

# Fitness function
def fitness(chromosome):
    x = int(chromosome, 2)
    return 10 * math.sin(x) + x

# Create initial population
def create_population():
    return [''.join(random.choice('01') for _ in range(CHROMOSOME_LENGTH)) for _ in range(POPULATION_SIZE)]

# Selection using fitness proportionate selection (roulette wheel)
def selection(population):
    fitness_values = [fitness(ind) for ind in population]
    total_fitness = sum(fitness_values)
    probabilities = [f / total_fitness for f in fitness_values]
    return random.choices(population, weights=probabilities, k=2)

# Crossover operation
def crossover(parent1, parent2):
    point = random.randint(1, CHROMOSOME_LENGTH - 1)
    child1 = parent1[:point] + parent2[point:]
    child2 = parent2[:point] + parent1[point:]
    return child1, child2

# Mutation operation
def mutation(chromosome):
    return ''.join(
        bit if random.random() > MUTATION_RATE else random.choice('01')
        for bit in chromosome
    )

# Genetic algorithm
def genetic_algorithm():
    population = create_population()
    print(f"Initial Population: {population}")

    for generation in range(GENERATIONS):
        new_population = []
        for _ in range(POPULATION_SIZE // 2):
            parent1, parent2 = selection(population)
            child1, child2 = crossover(parent1, parent2)
            child1 = mutation(child1)
            child2 = mutation(child2)
            new_population.extend([child1, child2])

        population = new_population
        best = max(population, key=fitness)
        best_x = int(best, 2)
        best_f = fitness(best)
        print(f"Generation {generation + 1}: best = {best} (x={best_x}, f={best_f:.2f})")

# Run the algorithm
genetic_algorithm()
# Out:
# Initial Population: ['10110', '11111', '10101', '00001', '10011', '10000']
# Generation 1: best = 10101 (x=21, f=29.37)
# Generation 2: best = 10101 (x=21, f=29.37)
# Generation 3: best = 10101 (x=21, f=29.37)
# Generation 4: best = 10101 (x=21, f=29.37)
# Generation 5: best = 10101 (x=21, f=29.37)
# Generation 6: best = 10101 (x=21, f=29.37)
# Generation 7: best = 10101 (x=21, f=29.37)
# Generation 8: best = 10101 (x=21, f=29.37)
# Generation 9: best = 10101 (x=21, f=29.37)
# Generation 10: best = 10101 (x=21, f=29.37)
# Generation 11: best = 10101 (x=21, f=29.37)
# Generation 12: best = 10101 (x=21, f=29.37)
# Generation 13: best = 10101 (x=21, f=29.37)
# Generation 14: best = 10101 (x=21, f=29.37)
# Generation 15: best = 10101 (x=21, f=29.37)
# Generation 16: best = 10101 (x=21, f=29.37)
# Generation 17: best = 10101 (x=21, f=29.37)
# Generation 18: best = 10101 (x=21, f=29.37)
# Generation 19: best = 10101 (x=21, f=29.37)
# Generation 20: best = 10101 (x=21, f=29.37)
# ...
